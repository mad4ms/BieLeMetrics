# %%
import sys
import os
sys.path.append("../")

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import json
# import sportsradar data reader
from src.etl_pipeline.models.DataClassGamePositions import DataClassGamePositions

# %%
path_to_data = "../data/raw/gameday_01/kinexon/2023-08-24_gd_01_id_42307421_teams_HCErlangen_vs_TSVHannover-Burgdorf_kinexon.csv"

# %%
data_game_positions = DataClassGamePositions(path_to_data)

# print head of data_positions
display(data_game_positions.data_positions.head())
# Out:
#         ts in ms     formatted local time  sensor id  mapped id  number  \
# 0  1692896452800  24.08.2023 19:00:52.800      45763        907      67
# 1  1692896452800  24.08.2023 19:00:52.800      45885       1160      26
# 2  1692896452800  24.08.2023 19:00:52.800     281278       1202      99
# 3  1692896452800  24.08.2023 19:00:52.800      45798         11      18
# 4  1692896452800  24.08.2023 19:00:52.800      45180          3      33
#
#              full name league id  group id             group name  x in m  \
# 0        Hampus Olsson    904942         1            HC Erlangen  33.414
# 1  Jonathan Edvardsson    905504         2  TSV Hannover-Burgdorf  18.685
# 2           Ball2 Ball  HCEBall2         3                   Ball  20.688
# 3  Sebastian Firnhaber    869458         1            HC Erlangen  32.551
# 4         Nikolai Link    124930         1            HC Erlangen  32.047
#
#    y in m
# 0  16.085
# 1  13.964
# 2  11.397
# 3  11.831
# 4   9.097
